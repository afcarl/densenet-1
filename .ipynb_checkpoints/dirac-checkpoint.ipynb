# %%
import numpy as np
import random
from matplotlib import pyplot as plt
from IPython.core.debugger import Tracer
from six.moves import cPickle 

# Fetch data with the following
#
#   wget http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
#   tar xzf cifar-10-python.tar.gz
# 

def load_batch(path):
    # https://stackoverflow.com/questions/35995999/why-cifar-10-images-are-not-displayed-properly-using-matplotlib
    f = open(path, 'rb')
    datadict = cPickle.load(f,encoding='latin1')
    f.close()
    X = datadict["data"] 
    Y = datadict['labels']
    X = X.reshape(10000, 3, 32, 32).transpose(0,2,3,1).astype("float32")
    X = X.reshape(10000, -1)
    Y = np.array(Y)
    return X, Y

im_batches = []
all_labels = []
for i in [1,2,3,4,5]:
    ims, labs = load_batch('/home/nbuser/cifar-10-batches-py/data_batch_%s' % i)
    im_batches.append(ims)
    all_labels.append(labs)
    
all_raw_images = np.vstack(im_batches)
all_labels = np.hstack(all_labels)

# %%
label_names = [    
'airplane',
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]
#Visualizing CIFAR 10

def show_images(images):
    # TODO: Add flag to unwhiten?
    fig, axes1 = plt.subplots(5,5,figsize=(3,3))
    for j in range(5):
        for k in range(5):
            i = np.random.choice(range(len(images)))
            axes1[j][k].set_axis_off()
            data = images[i:i+1][0].reshape(32, 32, 3).astype('uint8')
            axes1[j][k].imshow(data)
                
    plt.show()

# %%
for i in range(3):
    img = all_raw_images[i].reshape(32, 32, 3).astype('uint8')
    plt.imshow(img)
    plt.title(label_names[all_labels[i]])
    plt.show()

# %%
print(len(all_raw_images))

TRAINING_MEAN = np.mean(all_raw_images)
TRAINING_STD = np.std(all_raw_images)

def whiten(images):
    images = images - TRAINING_MEAN
    return images / TRAINING_STD
    
def unwhiten(images):
    images = images * TRAINING_STD
    return images + TRAINING_MEAN
    
images = whiten(all_raw_images)[:45000]
labels = all_labels[:45000]

val_images = whiten(all_raw_images)[45000:]
val_labels = all_labels[45000:]

all_raw_test_images, test_labels = load_batch('/home/nbuser/cifar-10-batches-py/test_batch')
test_images = whiten(all_raw_test_images)
test_labels = np.asarray(test_labels)
# Out:
# 50000

# %%
print(np.mean(images[0]), np.std(images[0]))

def show_whitened_image(image, label=None):
    image = unwhiten(image)
    image = image.reshape(32, 32, 3).astype("uint8")
    plt.imshow(image, interpolation="bicubic")
    if label:
        plt.title(label_names[label])
    plt.show()

for i in range(4):
    show_whitened_image(images[i], labels[i])
# Out:
# -0.269062 0.81019

# %%
print("Raw")
print(np.mean(all_raw_images))
print(np.var(all_raw_images))

print("Whitened")
print(np.mean(images))
print(np.var(images))

show_images(unwhiten(images))
# Out:
# Raw
# 120.708
# 4115.23
# Whitened
# 1.49569e-05
# 1.00126

# %%
print("Whitened Test")
print(np.mean(test_images))
print(np.var(test_images))

show_images(unwhiten(test_images))
print(len(test_images))
# Out:
# Whitened Test
# 0.0128064
# 0.997227
# 10000

# %%
import tensorflow as tf
print(tf.__version__)
from tensorflow.python.client import device_lib

def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU']

print(get_available_gpus())
# Out:
# 1.1.0
# ['/gpu:0']

# %%
# Set the seed for determinism
tf.reset_default_graph()
tf.set_random_seed(1)

# Build our models
input_size = 3*32*32
output_size = 10
batch_size = 50 # To use GPU correctly

def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1,1,1,1], padding='SAME')

def max_pool_2x2(x):
    """Use this to halve the size after a conv"""
    return tf.nn.max_pool(x, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')

def weight_var(shape):
    return tf.Variable(tf.truncated_normal(shape, stddev=0.1))

def bias_var(shape):
    return tf.Variable(tf.constant(0.1, shape=shape))

with tf.device('/gpu:0'):
    x = tf.placeholder(tf.float32, shape=(None, input_size))
    y_train = tf.placeholder(tf.int32, shape=(batch_size))

    # Conv weights
    W_conv1 = weight_var([5, 5, 3, 32])
    b1 = bias_var([32])
                
    W_conv2 =  weight_var([5, 5, 32, 64])
    b2 = bias_var([64])
    
    # Conv layers
    x_image = tf.reshape(x, [-1, 32, 32, 3]) # TODO: Is this correctly unwrapped?
    h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b1) # (28x28x32)
    h_pool1 = max_pool_2x2(h_conv1) # (16x16x32)
    
    h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b2) # (16x16x64)
    h_pool2 = max_pool_2x2(h_conv2) # (8x8x64)
    
    h_pool2_size = 8*8*64
    h_pool2_flat = tf.reshape(h_pool2, [-1, h_pool2_size])
    
    
    # FC weights
    W3 = weight_var([h_pool2_size, 1024])
    b3 = bias_var([1024])

    W4 = weight_var([1024, output_size])
    b4 = bias_var([output_size])
    
    # FC layers    
    h_fc = tf.nn.relu(tf.matmul(h_pool2_flat, W3) + b3)    

    keep_prob = tf.placeholder(tf.float32)
    h_fc_drop = tf.nn.dropout(h_fc, keep_prob)

    logits = tf.matmul(h_fc_drop, W4) + b4
    
    cross_entropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y_train, logits=logits)
    loss = tf.reduce_mean(cross_entropy)
    
    # Optimizers
    optimizer = tf.train.AdamOptimizer(learning_rate=0.001)
    # global_step = tf.Variable(0, trainable=False, name="global_step")
    # train_op = optimizer.minimize(loss, global_step=global_step)
    train_op = optimizer.minimize(loss)

sess = tf.InteractiveSession()

# %%
def check_accuracy(test_ims, test_ys):    
    total_correct = 0
    for i in range(len(test_ims) // batch_size):
        logits_out = sess.run(logits, feed_dict={
            x: test_ims[i*batch_size:(i+1)*batch_size],
            keep_prob: 1.0
        })

        y_pred = np.argmax(logits_out, 1)
        correct = (y_pred - test_ys[i*batch_size:(i+1)*batch_size]) == 0
        total_correct += correct

    acc = np.sum(total_correct) / len(test_ys)

    message = "%s correct out of %s => accuracy: %s" % ( np.sum(total_correct), len(test_ys), acc)
    return acc, message

# %%
report = {
    'loss': [],
    'val_acc': [],
}

def sample(images, labels, n=50):
    sample_indices = random.sample(range(len(images)), n)
    return images[sample_indices], labels[sample_indices]

n_epochs = 20

# Clear out the session
sess.run(tf.global_variables_initializer())
for i in range(n_epochs*1000+1):
    # Train with a minibatch

    train_ims, train_labels = sample(images, labels)
    _, l = sess.run([train_op, loss], feed_dict={
        x: train_ims,
        y_train: train_labels,
        keep_prob: 0.5,
    })

    if i % 50 == 0:
        report['loss'].append(l)
        acc, acc_msg = check_accuracy(*sample(val_images, val_labels, 1000))

        report['val_acc'].append(acc)
        
        
    if i % 200 == 0:
        print("\nIteration: %s loss: %s" % (i, l))
        print(acc_msg)
# Out:
# Iteration: 0 loss: 28.6224
# 91 correct out of 1000 => accuracy: 0.091
#
# Iteration: 200 loss: 1.96981
# 365 correct out of 1000 => accuracy: 0.365
#
# Iteration: 400 loss: 1.61193
# 394 correct out of 1000 => accuracy: 0.394
#
# Iteration: 600 loss: 1.69157
# 452 correct out of 1000 => accuracy: 0.452
#
# Iteration: 800 loss: 1.48432
# 456 correct out of 1000 => accuracy: 0.456
#
# Iteration: 1000 loss: 1.21387
# 521 correct out of 1000 => accuracy: 0.521
#
# Iteration: 1200 loss: 1.71834
# 528 correct out of 1000 => accuracy: 0.528
#
# Iteration: 1400 loss: 1.08028
# 530 correct out of 1000 => accuracy: 0.53
#
# Iteration: 1600 loss: 1.10225
# 563 correct out of 1000 => accuracy: 0.563
#
# Iteration: 1800 loss: 0.978958
# 583 correct out of 1000 => accuracy: 0.583
#
# Iteration: 2000 loss: 1.00222
# 619 correct out of 1000 => accuracy: 0.619
#
# Iteration: 2200 loss: 1.10166
# 583 correct out of 1000 => accuracy: 0.583
#
# Iteration: 2400 loss: 1.03387
# 618 correct out of 1000 => accuracy: 0.618
#
# Iteration: 2600 loss: 1.08336
# 642 correct out of 1000 => accuracy: 0.642
#
# Iteration: 2800 loss: 0.959507
# 625 correct out of 1000 => accuracy: 0.625
#
# Iteration: 3000 loss: 0.604947
# 661 correct out of 1000 => accuracy: 0.661
#
# Iteration: 3200 loss: 0.49858
# 639 correct out of 1000 => accuracy: 0.639
#
# Iteration: 3400 loss: 1.02406
# 662 correct out of 1000 => accuracy: 0.662
#
# Iteration: 3600 loss: 0.730477
# 679 correct out of 1000 => accuracy: 0.679
#
# Iteration: 3800 loss: 0.990255
# 643 correct out of 1000 => accuracy: 0.643
#
# Iteration: 4000 loss: 0.487024
# 684 correct out of 1000 => accuracy: 0.684
#
# Iteration: 4200 loss: 0.561579
# 664 correct out of 1000 => accuracy: 0.664
#
# Iteration: 4400 loss: 0.747493
# 644 correct out of 1000 => accuracy: 0.644
#
# Iteration: 4600 loss: 0.493258
# 677 correct out of 1000 => accuracy: 0.677
#
# Iteration: 4800 loss: 0.565911
# 690 correct out of 1000 => accuracy: 0.69
#
# Iteration: 5000 loss: 0.506933
# 662 correct out of 1000 => accuracy: 0.662
#
# Iteration: 5200 loss: 0.704767
# 692 correct out of 1000 => accuracy: 0.692
#
# Iteration: 5400 loss: 0.338802
# 680 correct out of 1000 => accuracy: 0.68
#
# Iteration: 5600 loss: 0.635069
# 688 correct out of 1000 => accuracy: 0.688
#
# Iteration: 5800 loss: 0.730522
# 666 correct out of 1000 => accuracy: 0.666
#
# Iteration: 6000 loss: 0.518278
# 686 correct out of 1000 => accuracy: 0.686
#
# Iteration: 6200 loss: 0.585392
# 704 correct out of 1000 => accuracy: 0.704
#
# Iteration: 6400 loss: 0.37861
# 690 correct out of 1000 => accuracy: 0.69
#
# Iteration: 6600 loss: 0.303837
# 699 correct out of 1000 => accuracy: 0.699
#
# Iteration: 6800 loss: 0.207272
# 700 correct out of 1000 => accuracy: 0.7
#
# Iteration: 7000 loss: 0.385244
# 722 correct out of 1000 => accuracy: 0.722
#
# Iteration: 7200 loss: 0.717504
# 706 correct out of 1000 => accuracy: 0.706
#
# Iteration: 7400 loss: 0.104485
# 697 correct out of 1000 => accuracy: 0.697
#
# Iteration: 7600 loss: 0.337852
# 699 correct out of 1000 => accuracy: 0.699
#
# Iteration: 7800 loss: 0.186515
# 681 correct out of 1000 => accuracy: 0.681
#
# Iteration: 8000 loss: 0.220028
# 711 correct out of 1000 => accuracy: 0.711
#
# Iteration: 8200 loss: 0.310097
# 695 correct out of 1000 => accuracy: 0.695
#
# Iteration: 8400 loss: 0.209126
# 707 correct out of 1000 => accuracy: 0.707
#
# Iteration: 8600 loss: 0.476201
# 703 correct out of 1000 => accuracy: 0.703
#
# Iteration: 8800 loss: 0.268633
# 700 correct out of 1000 => accuracy: 0.7
#
# Iteration: 9000 loss: 0.311301
# 727 correct out of 1000 => accuracy: 0.727
#
# Iteration: 9200 loss: 0.231076
# 696 correct out of 1000 => accuracy: 0.696
#
# Iteration: 9400 loss: 0.405156
# 696 correct out of 1000 => accuracy: 0.696
#
# Iteration: 9600 loss: 0.0490024
# 693 correct out of 1000 => accuracy: 0.693
#
# Iteration: 9800 loss: 0.231224
# 711 correct out of 1000 => accuracy: 0.711
#
# Iteration: 10000 loss: 0.194688
# 688 correct out of 1000 => accuracy: 0.688
#
# Iteration: 10200 loss: 0.149095
# 711 correct out of 1000 => accuracy: 0.711
#
# Iteration: 10400 loss: 0.147808
# 707 correct out of 1000 => accuracy: 0.707
#
# Iteration: 10600 loss: 0.230904
# 699 correct out of 1000 => accuracy: 0.699
#
# Iteration: 10800 loss: 0.185665
# 683 correct out of 1000 => accuracy: 0.683
#
# Iteration: 11000 loss: 0.253566
# 676 correct out of 1000 => accuracy: 0.676
#
# Iteration: 11200 loss: 0.242381
# 716 correct out of 1000 => accuracy: 0.716
#
# Iteration: 11400 loss: 0.308557
# 690 correct out of 1000 => accuracy: 0.69
#
# Iteration: 11600 loss: 0.0506288
# 679 correct out of 1000 => accuracy: 0.679
#
# Iteration: 11800 loss: 0.17344
# 692 correct out of 1000 => accuracy: 0.692
#
# Iteration: 12000 loss: 0.232761
# 711 correct out of 1000 => accuracy: 0.711
#
# Iteration: 12200 loss: 0.202503
# 675 correct out of 1000 => accuracy: 0.675
#
# Iteration: 12400 loss: 0.217506
# 704 correct out of 1000 => accuracy: 0.704
#
# Iteration: 12600 loss: 0.138485
# 694 correct out of 1000 => accuracy: 0.694
#
# Iteration: 12800 loss: 0.28858
# 686 correct out of 1000 => accuracy: 0.686
#
# Iteration: 13000 loss: 0.171334
# 708 correct out of 1000 => accuracy: 0.708
#
# Iteration: 13200 loss: 0.095825
# 698 correct out of 1000 => accuracy: 0.698
#
# Iteration: 13400 loss: 0.0717359
# 684 correct out of 1000 => accuracy: 0.684
#
# Iteration: 13600 loss: 0.0631541
# 695 correct out of 1000 => accuracy: 0.695
#
# Iteration: 13800 loss: 0.465904
# 691 correct out of 1000 => accuracy: 0.691
#
# Iteration: 14000 loss: 0.132894
# 711 correct out of 1000 => accuracy: 0.711
#
# Iteration: 14200 loss: 0.0975226
# 701 correct out of 1000 => accuracy: 0.701
#
# Iteration: 14400 loss: 0.249443
# 706 correct out of 1000 => accuracy: 0.706
#
# Iteration: 14600 loss: 0.044866
# 708 correct out of 1000 => accuracy: 0.708
#
# Iteration: 14800 loss: 0.138593
# 719 correct out of 1000 => accuracy: 0.719
#
# Iteration: 15000 loss: 0.249088
# 692 correct out of 1000 => accuracy: 0.692
#
# Iteration: 15200 loss: 0.0791514
# 706 correct out of 1000 => accuracy: 0.706
#
# Iteration: 15400 loss: 0.142983
# 712 correct out of 1000 => accuracy: 0.712
#
# Iteration: 15600 loss: 0.118286
# 698 correct out of 1000 => accuracy: 0.698
#
# Iteration: 15800 loss: 0.0276919
# 689 correct out of 1000 => accuracy: 0.689
#
# Iteration: 16000 loss: 0.198036
# 691 correct out of 1000 => accuracy: 0.691
#
# Iteration: 16200 loss: 0.162451
# 708 correct out of 1000 => accuracy: 0.708
#
# Iteration: 16400 loss: 0.12893
# 696 correct out of 1000 => accuracy: 0.696
#
# Iteration: 16600 loss: 0.13134
# 715 correct out of 1000 => accuracy: 0.715
#
# Iteration: 16800 loss: 0.0942896
# 677 correct out of 1000 => accuracy: 0.677
#
# Iteration: 17000 loss: 0.0701725
# 706 correct out of 1000 => accuracy: 0.706
#
# Iteration: 17200 loss: 0.0162973
# 677 correct out of 1000 => accuracy: 0.677
#
# Iteration: 17400 loss: 0.52743
# 682 correct out of 1000 => accuracy: 0.682
#
# Iteration: 17600 loss: 0.0471315
# 697 correct out of 1000 => accuracy: 0.697
#
# Iteration: 17800 loss: 0.101805
# 705 correct out of 1000 => accuracy: 0.705
#
# Iteration: 18000 loss: 0.107156
# 708 correct out of 1000 => accuracy: 0.708
#
# Iteration: 18200 loss: 0.301408
# 673 correct out of 1000 => accuracy: 0.673
#
# Iteration: 18400 loss: 0.110636
# 689 correct out of 1000 => accuracy: 0.689
#
# Iteration: 18600 loss: 0.610545
# 716 correct out of 1000 => accuracy: 0.716
#
# Iteration: 18800 loss: 0.198104
# 693 correct out of 1000 => accuracy: 0.693
#
# Iteration: 19000 loss: 0.025807
# 724 correct out of 1000 => accuracy: 0.724
#
# Iteration: 19200 loss: 0.170302
# 711 correct out of 1000 => accuracy: 0.711
#
# Iteration: 19400 loss: 0.128895
# 726 correct out of 1000 => accuracy: 0.726
#
# Iteration: 19600 loss: 0.337697
# 685 correct out of 1000 => accuracy: 0.685
#
# Iteration: 19800 loss: 0.106579
# 700 correct out of 1000 => accuracy: 0.7
#
# Iteration: 20000 loss: 0.138665
# 691 correct out of 1000 => accuracy: 0.691

# %%
def smooth(vals):
    window = 30    
    return np.convolve(vals, np.ones(window)/window, mode='valid')

plt.plot(smooth(np.log(report['loss'])))
plt.title("Loss")
plt.show()

plt.title("Validation accuracy")
ys = smooth(report['val_acc'][20:])
plt.plot(ys)
plt.show()

print("Final validation accuracy: %.1f%%" % (np.mean(report['val_acc'][-10:]) *100))

acc, _ = check_accuracy(test_images, test_labels)
print("Final test accuracy: %.1f%%" % (acc*100))
# Out:
# Final validation accuracy: 69.9%
# Final test accuracy: 69.2%

# %%
# Render misclassified data
test_ims = test_images
test_ys = test_labels

total_correct = 0
wrongs = []
for i in range(len(test_ims) // batch_size):
    logits_out = sess.run(logits, feed_dict={
        x: test_ims[i*batch_size:(i+1)*batch_size],
        keep_prob: 1.
    })
    
    y_pred = np.argmax(logits_out, 1)
    incorrect_idxs, = np.where((y_pred - test_ys[i*batch_size:(i+1)*batch_size]) != 0)
    wrongs = np.concatenate([wrongs, incorrect_idxs + batch_size*i])

# %%
print("Showing broken images")
for idx in range(100):
# for idx in wrongs[10:20]:
    im = test_ims[int(idx)]
    logits_out = sess.run(logits, feed_dict={
        x: [im],
        keep_prob: 1.
    })

    show_whitened_image(im)
    plt.title("pred: %s   actual: %s" % (label_names[np.argmax(logits_out, 1)], 
                                         label_names[test_labels[int(idx)]]
                                        ))
